# %%
from nltk.parse.stanford import StanfordDependencyParser
import os

# %%
os.environ['JAVAHOME'] = r'/Library/Internet Plug-Ins/JavaAppletPlugin.plugin/Contents/Home/bin/java'

scp = StanfordDependencyParser(
    path_to_jar = './stanford/stanford-parser-full-2018-10-17/stanford-parser.jar',
    path_to_models_jar = './stanford/stanford-parser-full-2018-10-17/stanford-parser-3.9.2-models.jar',
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: The StanfordDependencyParser will be deprecated
# Please use nltk.parse.corenlp.CoreNLPDependencyParser instead.
#   """

# %%
result = list(scp.raw_parse('Sarah read the book quickly and didn\'t understood it correctly.'))

# %%
result[0]
# Out:
# <DependencyGraph with 12 nodes>
